# %%
#!uv add datasets swanlab -q
#!wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1a0sf5C209CLW5824TJkUM4olMy0zZWpg' -O fake_sft.json

# %%
from datasets import Dataset
import pandas as pd
from transformers import AutoTokenizer,AutoModelForCausalLM,DataCollatorForSeq2Seq, TrainingArguments, Trainer, GenerationConfig
from peft import LoraConfig, TaskType, get_peft_model
import torch

# %%
df=pd.read_json("./data/fake_sft.json")
ds=Dataset.from_pandas(df)
ds
# Out:
# Dataset({
#     features: ['system', 'instruction', 'input', 'output'],
#     num_rows: 300
# })

# %%
df[:3]
# Out:
#                                               system  ...                                             output
# 0  将文本中的name、address、email、question提取出来，以json格式输出...  ...  ```json\n{\n    "name": "龙琳",\n    "address": ...
# 1  将文本中的name、address、email、question提取出来，以json格式输出...  ...  ```json\n{\n    "name": "周飞",\n    "address": ...
# 2  将文本中的name、address、email、question提取出来，以json格式输出...  ...  ```json\n{\n    "name": "林桂兰",\n    "address":...
#
# [3 rows x 4 columns]

# %%
model_id = "Qwen/Qwen3-0.6B"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id, use_fast=False)
tokenizer
# Out:
# ---------------------------------------------------------------------------
# ConnectTimeout                            Traceback (most recent call last)
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tokenizer = AutoTokenizer.from_pretrained(model_id, use_fast=False)
#       2 tokenizer
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/transformers/models/auto/tokenization_auto.py:1156, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1152     if tokenizer_class is None:
#    1153         raise ValueError(
#    1154             f"Tokenizer class {tokenizer_class_candidate} does not exist or is not currently imported."
#    1155         )
# -> 1156     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1158 # Otherwise we have to be creative.
#    1159 # if model is an encoder decoder, the encoder tokenizer class is used by default
#    1160 if isinstance(config, EncoderDecoderConfig):
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:2039, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2035             vocab_files[f"chat_template_{template_name}"] = (
#    2036                 f"{CHAT_TEMPLATE_DIR}/{template_file.name}"
#    2037             )
#    2038 else:
# -> 2039     for template in list_repo_templates(
#    2040         pretrained_model_name_or_path,
#    2041         local_files_only=local_files_only,
#    2042         revision=revision,
#    2043         cache_dir=cache_dir,
#    2044         token=token,
#    2045     ):
#    2046         template = template.removesuffix(".jinja")
#    2047         vocab_files[f"chat_template_{template}"] = f"{CHAT_TEMPLATE_DIR}/{template}.jinja"
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/transformers/utils/hub.py:169, in list_repo_templates(repo_id, local_files_only, revision, cache_dir, token)
#     165 if not local_files_only:
#     166     try:
#     167         return [
#     168             entry.path.removeprefix(f"{CHAT_TEMPLATE_DIR}/")
# --> 169             for entry in list_repo_tree(
#     170                 repo_id=repo_id,
#     171                 revision=revision,
#     172                 path_in_repo=CHAT_TEMPLATE_DIR,
#     173                 recursive=False,
#     174                 token=token,
#     175             )
#     176             if entry.path.endswith(".jinja")
#     177         ]
#     178     except (GatedRepoError, RepositoryNotFoundError, RevisionNotFoundError):
#     179         raise  # valid errors => do not catch
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/huggingface_hub/hf_api.py:3156, in list_repo_tree(self, repo_id, path_in_repo, recursive, expand, revision, repo_type, token)
#    3062 @validate_hf_hub_args
#    3063 def list_repo_tree(
#    3064     self,
#    (...)   3072     token: Union[str, bool, None] = None,
#    3073 ) -> Iterable[Union[RepoFile, RepoFolder]]:
#    3074     """
#    3075     List a repo tree's files and folders and get information about them.
#    3076
#    3077     Args:
#    3078         repo_id (`str`):
#    3079             A namespace (user or an organization) and a repo name separated by a `/`.
#    3080         path_in_repo (`str`, *optional*):
#    3081             Relative path of the tree (folder) in the repo, for example:
#    3082             `"checkpoints/1fec34a/results"`. Will default to the root tree (folder) of the repository.
#    3083         recursive (`bool`, *optional*, defaults to `False`):
#    3084             Whether to list tree's files and folders recursively.
#    3085         expand (`bool`, *optional*, defaults to `False`):
#    3086             Whether to fetch more information about the tree's files and folders (e.g. last commit and files' security scan results). This
#    3087             operation is more expensive for the server so only 50 results are returned per page (instead of 1000).
#    3088             As pagination is implemented in `huggingface_hub`, this is transparent for you except for the time it
#    3089             takes to get the results.
#    3090         revision (`str`, *optional*):
#    3091             The revision of the repository from which to get the tree. Defaults to `"main"` branch.
#    3092         repo_type (`str`, *optional*):
#    3093             The type of the repository from which to get the tree (`"model"`, `"dataset"` or `"space"`.
#    3094             Defaults to `"model"`.
#    3095         token (`bool` or `str`, *optional*):
#    3096             A valid user access token (string). Defaults to the locally saved
#    3097             token, which is the recommended method for authentication (see
#    3098             https://huggingface.co/docs/huggingface_hub/quick-start#authentication).
#    3099             To disable authentication, pass `False`.
#    3100
#    3101     Returns:
#    3102         `Iterable[Union[RepoFile, RepoFolder]]`:
#    3103             The information about the tree's files and folders, as an iterable of [`RepoFile`] and [`RepoFolder`] objects. The order of the files and folders is
#    3104             not guaranteed.
#    3105
#    3106     Raises:
#    3107         [`~utils.RepositoryNotFoundError`]:
#    3108             If repository is not found (error 404): wrong repo_id/repo_type, private but not authenticated or repo
#    3109             does not exist.
#    3110         [`~utils.RevisionNotFoundError`]:
#    3111             If revision is not found (error 404) on the repo.
#    3112         [`~utils.EntryNotFoundError`]:
#    3113             If the tree (folder) does not exist (error 404) on the repo.
#    3114
#    3115     Examples:
#    3116
#    3117         Get information about a repo's tree.
#    3118         ```py
#    3119         >>> from huggingface_hub import list_repo_tree
#    3120         >>> repo_tree = list_repo_tree("lysandre/arxiv-nlp")
#    3121         >>> repo_tree
#    3122         <generator object HfApi.list_repo_tree at 0x7fa4088e1ac0>
#    3123         >>> list(repo_tree)
#    3124         [
#    3125             RepoFile(path='.gitattributes', size=391, blob_id='ae8c63daedbd4206d7d40126955d4e6ab1c80f8f', lfs=None, last_commit=None, security=None),
#    3126             RepoFile(path='README.md', size=391, blob_id='43bd404b159de6fba7c2f4d3264347668d43af25', lfs=None, last_commit=None, security=None),
#    3127             RepoFile(path='config.json', size=554, blob_id='2f9618c3a19b9a61add74f70bfb121335aeef666', lfs=None, last_commit=None, security=None),
#    3128             RepoFile(
#    3129                 path='flax_model.msgpack', size=497764107, blob_id='8095a62ccb4d806da7666fcda07467e2d150218e',
#    3130                 lfs={'size': 497764107, 'sha256': 'd88b0d6a6ff9c3f8151f9d3228f57092aaea997f09af009eefd7373a77b5abb9', 'pointer_size': 134}, last_commit=None, security=None
#    3131             ),
#    3132             RepoFile(path='merges.txt', size=456318, blob_id='226b0752cac7789c48f0cb3ec53eda48b7be36cc', lfs=None, last_commit=None, security=None),
#    3133             RepoFile(
#    3134                 path='pytorch_model.bin', size=548123560, blob_id='64eaa9c526867e404b68f2c5d66fd78e27026523',
#    3135                 lfs={'size': 548123560, 'sha256': '9be78edb5b928eba33aa88f431551348f7466ba9f5ef3daf1d552398722a5436', 'pointer_size': 134}, last_commit=None, security=None
#    3136             ),
#    3137             RepoFile(path='vocab.json', size=898669, blob_id='b00361fece0387ca34b4b8b8539ed830d644dbeb', lfs=None, last_commit=None, security=None)]
#    3138         ]
#    3139         ```
#    3140
#    3141         Get even more information about a repo's tree (last commit and files' security scan results)
#    3142         ```py
#    3143         >>> from huggingface_hub import list_repo_tree
#    3144         >>> repo_tree = list_repo_tree("prompthero/openjourney-v4", expand=True)
#    3145         >>> list(repo_tree)
#    3146         [
#    3147             RepoFolder(
#    3148                 path='feature_extractor',
#    3149                 tree_id='aa536c4ea18073388b5b0bc791057a7296a00398',
#    3150                 last_commit={
#    3151                     'oid': '47b62b20b20e06b9de610e840282b7e6c3d51190',
#    3152                     'title': 'Upload diffusers weights (#48)',
#    3153                     'date': datetime.datetime(2023, 3, 21, 9, 5, 27, tzinfo=datetime.timezone.utc)
#    3154                 }
#    3155             ),
# -> 3156             RepoFolder(
#    3157                 path='safety_checker',
#    3158                 tree_id='65aef9d787e5557373fdf714d6c34d4fcdd70440',
#    3159                 last_commit={
#    3160                     'oid': '47b62b20b20e06b9de610e840282b7e6c3d51190',
#    3161                     'title': 'Upload diffusers weights (#48)',
#    3162                     'date': datetime.datetime(2023, 3, 21, 9, 5, 27, tzinfo=datetime.timezone.utc)
#    3163                 }
#    3164             ),
#    3165             RepoFile(
#    3166                 path='model_index.json',
#    3167                 size=582,
#    3168                 blob_id='d3d7c1e8c3e78eeb1640b8e2041ee256e24c9ee1',
#    3169                 lfs=None,
#    3170                 last_commit={
#    3171                     'oid': 'b195ed2d503f3eb29637050a886d77bd81d35f0e',
#    3172                     'title': 'Fix deprecation warning by changing `CLIPFeatureExtractor` to `CLIPImageProcessor`. (#54)',
#    3173                     'date': datetime.datetime(2023, 5, 15, 21, 41, 59, tzinfo=datetime.timezone.utc)
#    3174                 },
#    3175                 security={
#    3176                     'safe': True,
#    3177                     'av_scan': {'virusFound': False, 'virusNames': None},
#    3178                     'pickle_import_scan': None
#    3179                 }
#    3180             )
#    3181             ...
#    3182         ]
#    3183         ```
#    3184     """
#    3185     repo_type = repo_type or constants.REPO_TYPE_MODEL
#    3186     revision = quote(revision, safe="") if revision is not None else constants.DEFAULT_REVISION
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_pagination.py:36, in paginate(path, params, headers)
#      28 """Fetch a list of models/datasets/spaces and paginate through results.
#      29
#      30 This is using the same "Link" header format as GitHub.
#    (...)     33 - https://docs.github.com/en/rest/guides/traversing-with-pagination#link-header
#      34 """
#      35 session = get_session()
# ---> 36 r = session.get(path, params=params, headers=headers)
#      37 hf_raise_for_status(r)
#      38 yield from r.json()
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpx/_client.py:1053, in Client.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1036 def get(
#    1037     self,
#    1038     url: URL | str,
#    (...)   1046     extensions: RequestExtensions | None = None,
#    1047 ) -> Response:
#    1048     """
#    1049     Send a `GET` request.
#    1050
#    1051     **Parameters**: See `httpx.request`.
#    1052     """
# -> 1053     return self.request(
#    1054         "GET",
#    1055         url,
#    1056         params=params,
#    1057         headers=headers,
#    1058         cookies=cookies,
#    1059         auth=auth,
#    1060         follow_redirects=follow_redirects,
#    1061         timeout=timeout,
#    1062         extensions=extensions,
#    1063     )
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     235 import httpcore
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~/codespace/yao/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectTimeout: timed out
